# %%
import seaborn as sns
tips_data=sns.load_dataset("tips")
dow_data=sns.load_dataset("dowjones")

# %%
# sns.catplot(tips_data,x="tip",y="day",hue="sex",kind="strip")
sns.stripplot(tips_data,x="tip",y="day",hue="sex")
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
sns.swarmplot(tips_data,x="tip",y="day",hue="sex")
# Out:
# <Axes: xlabel='tip', ylabel='day'>
# c:\Users\DELL\Documents\Numpy\anuj\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\DELL\Documents\Numpy\anuj\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 6.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(tips_data,x="tip",y="day",hue="sex")
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
sns.violinplot(tips_data,x="tip",y="day",hue="sex")
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
sns.boxenplot(tips_data,x="tip",y="day",hue="sex")
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
sns.barplot(tips_data,x="day",y="tip",hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.countplot(tips_data,x="day",hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.pointplot(tips_data,x="tip",y="day")
# Out:
# <Axes: xlabel='tip', ylabel='day'>
